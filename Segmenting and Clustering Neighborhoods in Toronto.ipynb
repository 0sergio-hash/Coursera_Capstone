# %% [markdown]
# # Q1 : Scrape webpage and create initial dataframe

# %% [markdown]
# ## Imports/Installs

# %%
from bs4 import BeautifulSoup as bs #scraping
import requests #for downloading webpage
import pandas as pd #for handling data

# %% [markdown]
# ## Scraping webpage and creating dataframe

# %%
#define url for scraping
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %%
#download webpage contents
data = requests.get(url).text

# %%
#create BeautifulSoup object
soup = bs(data,'html5lib')

# %%
table_contents=[]
table=soup.find('table')
for row in table.findAll('td'):
    cell = {}
    if row.span.text=='Not assigned':
        pass
    else:
        cell['PostalCode'] = row.p.text[:3]
        cell['Borough'] = (row.span.text).split('(')[0]
        cell['Neighborhood'] = (((((row.span.text).split('(')[1]).strip(')')).replace(' /',',')).replace(')',' ')).strip(' ')
        table_contents.append(cell) 

# print(table_contents)
df=pd.DataFrame(table_contents)
df['Borough']=df['Borough'].replace({'Downtown TorontoStn A PO Boxes25 The Esplanade':'Downtown Toronto Stn A',
                                             'East TorontoBusiness reply mail Processing Centre969 Eastern':'East Toronto Business',
                                             'EtobicokeNorthwest':'Etobicoke Northwest','East YorkEast Toronto':'East York/East Toronto',
                                             'MississaugaCanada Post Gateway Processing Centre':'Mississauga'})
df
# Out:
#     PostalCode                Borough  \
# 0          M3A             North York
# 1          M4A             North York
# 2          M5A       Downtown Toronto
# 3          M6A             North York
# 4          M7A           Queen's Park
# ..         ...                    ...
# 98         M8X              Etobicoke
# 99         M4Y       Downtown Toronto
# 100        M7Y  East Toronto Business
# 101        M8Y              Etobicoke
# 102        M8Z              Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4                        Ontario Provincial Government
# ..                                                 ...
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100                                     Enclave of M4L
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 102  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# # Q2 : Append latitude and longitude coordinates to our dataframe

# %%
#pip install geocoder

# %%
#import geocoder

# %% [markdown]
# ## Geocoder timed out, using csv instead

# %%
postal = pd.read_csv('C:/Users/Administrator.Sergio-PC/Desktop/Geospatial_Coordinates.csv')
postal
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# ..          ...        ...        ...
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %%
df['Latitude'] = postal['Latitude']
df['Longitude'] = postal['Longitude']
df
# Out:
#     PostalCode                Borough  \
# 0          M3A             North York
# 1          M4A             North York
# 2          M5A       Downtown Toronto
# 3          M6A             North York
# 4          M7A           Queen's Park
# ..         ...                    ...
# 98         M8X              Etobicoke
# 99         M4Y       Downtown Toronto
# 100        M7Y  East Toronto Business
# 101        M8Y              Etobicoke
# 102        M8Z              Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                            Parkwoods  43.806686 -79.194353
# 1                                     Victoria Village  43.784535 -79.160497
# 2                            Regent Park, Harbourfront  43.763573 -79.188711
# 3                     Lawrence Manor, Lawrence Heights  43.770992 -79.216917
# 4                        Ontario Provincial Government  43.773136 -79.239476
# ..                                                 ...        ...        ...
# 98       The Kingsway, Montgomery Road, Old Mill North  43.706876 -79.518188
# 99                                Church and Wellesley  43.696319 -79.532242
# 100                                     Enclave of M4L  43.688905 -79.554724
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...  43.739416 -79.588437
# 102  Mimico NW, The Queensway West, South of Bloor,...  43.706748 -79.594054
#
# [103 rows x 5 columns]

# %% [markdown]
# # Q3: Explore and cluster

# %% [markdown]
# ## Create a new dataframe of only neighborhoods with Toronto in the name

# %%
df_Toronto = df[df['Borough'].str.contains('Toronto')] 
df_Toronto
# Out:
#     PostalCode                 Borough  \
# 2          M5A        Downtown Toronto
# 9          M5B        Downtown Toronto
# 15         M5C        Downtown Toronto
# 19         M4E            East Toronto
# 20         M5E        Downtown Toronto
# 24         M5G        Downtown Toronto
# 25         M6G        Downtown Toronto
# 30         M5H        Downtown Toronto
# 31         M6H            West Toronto
# 35         M4J  East York/East Toronto
# 36         M5J        Downtown Toronto
# 37         M6J            West Toronto
# 41         M4K            East Toronto
# 42         M5K        Downtown Toronto
# 43         M6K            West Toronto
# 47         M4L            East Toronto
# 48         M5L        Downtown Toronto
# 54         M4M            East Toronto
# 61         M4N         Central Toronto
# 62         M5N         Central Toronto
# 67         M4P         Central Toronto
# 68         M5P         Central Toronto
# 69         M6P            West Toronto
# 73         M4R         Central Toronto
# 74         M5R         Central Toronto
# 75         M6R            West Toronto
# 79         M4S         Central Toronto
# 80         M5S        Downtown Toronto
# 81         M6S            West Toronto
# 83         M4T         Central Toronto
# 84         M5T        Downtown Toronto
# 86         M4V         Central Toronto
# 87         M5V        Downtown Toronto
# 91         M4W        Downtown Toronto
# 92         M5W  Downtown Toronto Stn A
# 96         M4X        Downtown Toronto
# 97         M5X        Downtown Toronto
# 99         M4Y        Downtown Toronto
# 100        M7Y   East Toronto Business
#
#                                           Neighborhood   Latitude  Longitude
# 2                            Regent Park, Harbourfront  43.763573 -79.188711
# 9                             Garden District, Ryerson  43.692657 -79.264848
# 15                                      St. James Town  43.799525 -79.318389
# 19                                         The Beaches  43.786947 -79.385975
# 20                                         Berczy Park  43.757490 -79.374714
# 24                                  Central Bay Street  43.782736 -79.442259
# 25                                            Christie  43.753259 -79.329656
# 30                            Richmond, Adelaide, King  43.737473 -79.464763
# 31                        Dufferin, Dovercourt Village  43.739015 -79.506944
# 35                                  The Danforth  East  43.706397 -79.309937
# 36   Harbourfront East, Union Station, Toronto Islands  43.695344 -79.318389
# 37                            Little Portugal, Trinity  43.676357 -79.293031
# 41                        The Danforth West, Riverdale  43.679557 -79.352188
# 42            Toronto Dominion Centre, Design Exchange  43.668999 -79.315572
# 43        Brockton, Parkdale Village, Exhibition Place  43.659526 -79.340923
# 47                      India Bazaar, The Beaches West  43.704324 -79.388790
# 48                      Commerce Court, Victoria Hotel  43.689574 -79.383160
# 54                                     Studio District  43.657162 -79.378937
# 61                                       Lawrence Park  43.648198 -79.379817
# 62                                            Roselawn  43.733283 -79.419750
# 67                                    Davisville North  43.653206 -79.400049
# 68                            Forest Hill North & West  43.628947 -79.394420
# 69                       High Park, The Junction South  43.646435 -79.374846
# 73                                  North Toronto West  43.693781 -79.428191
# 74                 The Annex, North Midtown, Yorkville  43.689026 -79.453512
# 75                              Parkdale, Roncesvalles  43.669542 -79.422564
# 79                                          Davisville  43.713756 -79.490074
# 80                      University of Toronto, Harbord  43.691116 -79.476013
# 81                                  Runnymede, Swansea  43.673185 -79.487262
# 83                         Moore Park, Summerhill East  43.648960 -79.456325
# 84           Kensington Market, Chinatown, Grange Park  43.651571 -79.484450
# 86   Summerhill West, Rathnelly, South Hill, Forest...  43.636966 -79.615819
# 87   CN Tower, King and Spadina, Railway Lands, Har...  43.662744 -79.321558
# 91                                            Rosedale  43.636258 -79.498509
# 92                                      Enclave of M5E  43.628841 -79.520999
# 96                         St. James Town, Cabbagetown  43.756303 -79.565963
# 97              First Canadian Place, Underground city  43.724766 -79.532242
# 99                                Church and Wellesley  43.696319 -79.532242
# 100                                     Enclave of M4L  43.688905 -79.554724

# %% [markdown]
# ## Import additional needed libraries

# %%
import numpy as np
import json
#!conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim
import requests
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans

# %%
#!pip install folium

# %%
import folium

print('Libraries imported! :)')
# Out:
# Libraries imported! :)

# %% [markdown]
# ## Create a map of Toronto

# %% [markdown]
# 1. Define user agent
# 2. Initialize map of Toronto

# %%
#Define user agent, get coordinates of Toronto
address = 'Toronto,Ontario'

geolocator = Nominatim(user_agent = 'Canada_explorer')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

print('The geographical coordinates of Toronto are {},{}.'.format(latitude,longitude))
# Out:
# The geographical coordinates of Toronto are 43.6534817,-79.3839347.

# %%
#Create a map of Toronto using our coordinates

map_Toronto = folium.Map(location = [latitude,longitude], zoom_start = 10)

map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_6606c544fe95417490846126dd8da404%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_6606c544fe95417490846126dd8da404%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_6606c544fe95417490846126dd8da404%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_6606c544fe95417490846126dd8da404%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## Use foursquare API to explore neighborhoods

# %% [markdown]
# Start by defining user credentials

# %%
CLIENT_ID = 'DVLMGSHW5ZXGOPKUJIMG0P4TH4CRUQ0K3AYQCFO3VEK4MOCK'
CLIENT_SECRET = 'RKEGR051LSDZEPTWUROZ3NPPSY5DXXWKGLYYW4EYPFGEDP03'
ACCESS_TOKEN = 'CQWUXEOI30MJUDWUD2Z2NMAUX3F22IPEWAREZPCJXI2OBRSF'
VERSION = '20180605'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: DVLMGSHW5ZXGOPKUJIMG0P4TH4CRUQ0K3AYQCFO3VEK4MOCK
# CLIENT_SECRET:RKEGR051LSDZEPTWUROZ3NPPSY5DXXWKGLYYW4EYPFGEDP03

# %% [markdown]
# Next, we define function(s) to extract venue category and to get nearby venues

# %%
def getNearbyVenues(names,latitudes,longitudes,radius=500):
    venues_list = []
    for name,lat,lng in zip(names,latitudes,longitudes):
        print(name)
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID,CLIENT_SECRET,VERSION,lat,lng,radius,LIMIT)
        results = requests.get(url).json()['response']['groups'][0]['items']
        venues_list.append([(name,lat,lng,v['venue']['name'],v['venue']['location']['lat'],v['venue']['location']['lng'],v['venue']['categories'][0]['name']) for v in results])
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood','Neighborhood latitude','Neighborhood longitude','Venue','Venue latitude','Venue longitude','Venue category']
    return(nearby_venues)

# %% [markdown]
# Get the nearby venues for all of the neighborhoods in Toronto and store them in a new dataframe

# %%
Toronto_venues = getNearbyVenues(names=df_Toronto['Neighborhood'],latitudes=df_Toronto['Latitude'],longitudes=df_Toronto['Longitude'])

Toronto_venues.head()
# Out:
# Regent Park, Harbourfront
# Garden District, Ryerson
# St. James Town
# The Beaches
# Berczy Park
# Central Bay Street
# Christie
# Richmond, Adelaide, King
# Dufferin, Dovercourt Village
# The Danforth  East
# Harbourfront East, Union Station, Toronto Islands
# Little Portugal, Trinity
# The Danforth West, Riverdale
# Toronto Dominion Centre, Design Exchange
# Brockton, Parkdale Village, Exhibition Place
# India Bazaar, The Beaches West
# Commerce Court, Victoria Hotel
# Studio District
# Lawrence Park
# Roselawn
# Davisville North
# Forest Hill North & West
# High Park, The Junction South
# North Toronto West
# The Annex, North Midtown, Yorkville
# Parkdale, Roncesvalles
# Davisville
# University of Toronto, Harbord
# Runnymede, Swansea
# Moore Park, Summerhill East
# Kensington Market, Chinatown, Grange Park
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Rosedale
# Enclave of M5E
# St. James Town, Cabbagetown
# First Canadian Place, Underground city
# Church and Wellesley
# Enclave of M4L
#                 Neighborhood  Neighborhood latitude  Neighborhood longitude  \
# 0  Regent Park, Harbourfront              43.763573              -79.188711
# 1  Regent Park, Harbourfront              43.763573              -79.188711
# 2  Regent Park, Harbourfront              43.763573              -79.188711
# 3  Regent Park, Harbourfront              43.763573              -79.188711
# 4  Regent Park, Harbourfront              43.763573              -79.188711
#
#                    Venue  Venue latitude  Venue longitude       Venue category
# 0         RBC Royal Bank       43.766790       -79.191151                 Bank
# 1      G & G Electronics       43.765309       -79.191537    Electronics Store
# 2             Sail Sushi       43.765951       -79.191275           Restaurant
# 3       Big Bite Burrito       43.766299       -79.190720   Mexican Restaurant
# 4  Enterprise Rent-A-Car       43.764076       -79.193406  Rental Car Location

# %% [markdown]
# ##  Analyze the neighborhoods

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#one hot encoding
Toronto_onehot = pd.get_dummies(Toronto_venues[['Venue category']],prefix="",prefix_sep="")

#add neighborhood column to our new onehot dataframe
Toronto_onehot['Neighborhood'] = Toronto_venues['Neighborhood']

# %%
#print df size
Toronto_onehot.shape
# Out:
# (755, 202)

# %%
#group rows by neighborhood and mean occurance of categories

Toronto_grouped = Toronto_onehot.groupby('Neighborhood').mean().reset_index()

#print shape to confirm changes
Toronto_grouped.shape
# Out:
# (38, 202)

# %% [markdown]
# ## Get most common venues and put them into a dataframe

# %%
#Define a function that sorts venues in descending order

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
#create dataframe to display top 10 venues for each neighborhood

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = Toronto_grouped['Neighborhood']

for ind in np.arange(Toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0       Brockton, Parkdale Village, Exhibition Place           Coffee Shop
# 1  CN Tower, King and Spadina, Railway Lands, Har...            Comic Shop
# 2                                 Central Bay Street         Grocery Store
# 3                                           Christie                  Park
# 4                               Church and Wellesley           Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0               Brewery                  Café   American Restaurant
# 1         Auto Workshop            Restaurant         Burrito Place
# 2           Coffee Shop              Pharmacy           Pizza Place
# 3     Food & Drink Shop                 Diner  Ethiopian Restaurant
# 4           Pizza Place        Sandwich Place            Playground
#
#   5th Most Common Venue        6th Most Common Venue 7th Most Common Venue  \
# 0                Bakery                    Gastropub           Yoga Studio
# 1      Recording Studio                   Skate Park    Light Rail Station
# 2           Supermarket                  Yoga Studio          Dessert Shop
# 3     Electronics Store  Eastern European Restaurant   Dumpling Restaurant
# 4    Chinese Restaurant                 Intersection        Discount Store
#
#          8th Most Common Venue 9th Most Common Venue  \
# 0      Comfort Food Restaurant           Cheese Shop
# 1               Farmers Market  Fast Food Restaurant
# 2  Eastern European Restaurant   Dumpling Restaurant
# 3                   Donut Shop      Doner Restaurant
# 4                  Yoga Studio                 Diner
#
#         10th Most Common Venue
# 0               Clothing Store
# 1                          Spa
# 2                   Donut Shop
# 3                      Dog Run
# 4  Eastern European Restaurant

# %% [markdown]
# ## Cluster the neighborhoods

# %% [markdown]
#  Run K-Means and split the neighborhoods into 5 clusters

# %%
# set number of clusters
kclusters = 5

Toronto_grouped_clustering = Toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([1, 1, 1, 2, 1, 1, 1, 1, 1, 1])

# %% [markdown]
# Create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

Toronto_merged = df_Toronto

# merge Toronto_grouped with df_Toronto to add latitude/longitude for each neighborhood
Toronto_merged = Toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

Toronto_merged.head()
# Out:
#    PostalCode           Borough               Neighborhood   Latitude  \
# 2         M5A  Downtown Toronto  Regent Park, Harbourfront  43.763573
# 9         M5B  Downtown Toronto   Garden District, Ryerson  43.692657
# 15        M5C  Downtown Toronto             St. James Town  43.799525
# 19        M4E      East Toronto                The Beaches  43.786947
# 20        M5E  Downtown Toronto                Berczy Park  43.757490
#
#     Longitude  Cluster Labels 1st Most Common Venue  2nd Most Common Venue  \
# 2  -79.188711             1.0        Breakfast Spot         Medical Center
# 9  -79.264848             1.0          Skating Rink  General Entertainment
# 15 -79.318389             1.0        Breakfast Spot               Gym Pool
# 19 -79.385975             1.0   Japanese Restaurant     Chinese Restaurant
# 20 -79.374714             NaN                   NaN                    NaN
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 2      Electronics Store          Intersection            Restaurant
# 9        College Stadium                  Café                 Diner
# 15                  Bank    Chinese Restaurant          Intersection
# 19                  Bank                  Café           Yoga Studio
# 20                   NaN                   NaN                   NaN
#
#    6th Most Common Venue 7th Most Common Venue        8th Most Common Venue  \
# 2    Rental Car Location                  Bank           Mexican Restaurant
# 9   Ethiopian Restaurant     Electronics Store  Eastern European Restaurant
# 15           Pizza Place          Camera Store                     Pharmacy
# 19   Distribution Center    Falafel Restaurant         Ethiopian Restaurant
# 20                   NaN                   NaN                          NaN
#
#           9th Most Common Venue       10th Most Common Venue
# 2   Eastern European Restaurant          Dumpling Restaurant
# 9           Dumpling Restaurant                   Donut Shop
# 15                  Coffee Shop         Fast Food Restaurant
# 19            Electronics Store  Eastern European Restaurant
# 20                          NaN                          NaN

# %% [markdown]
# Finally, let's visualize the resulting clusters

# %%
#see the rows with Nan values
Toronto_merged[Toronto_merged.isna().any(axis=1)]
# Out:
#    PostalCode           Borough Neighborhood  Latitude  Longitude  \
# 20        M5E  Downtown Toronto  Berczy Park  43.75749 -79.374714
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 20             NaN                   NaN                   NaN
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 20                   NaN                   NaN                   NaN
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 20                   NaN                   NaN                   NaN
#
#    9th Most Common Venue 10th Most Common Venue
# 20                   NaN                    NaN

# %%
#Drop rows with Nan values
Toronto_merged.dropna(inplace=True)
Toronto_merged.reset_index(drop=True,inplace=True)
Toronto_merged
# Out:
#    PostalCode                 Borough  \
# 0         M5A        Downtown Toronto
# 1         M5B        Downtown Toronto
# 2         M5C        Downtown Toronto
# 3         M4E            East Toronto
# 4         M5G        Downtown Toronto
# 5         M6G        Downtown Toronto
# 6         M5H        Downtown Toronto
# 7         M6H            West Toronto
# 8         M4J  East York/East Toronto
# 9         M5J        Downtown Toronto
# 10        M6J            West Toronto
# 11        M4K            East Toronto
# 12        M5K        Downtown Toronto
# 13        M6K            West Toronto
# 14        M4L            East Toronto
# 15        M5L        Downtown Toronto
# 16        M4M            East Toronto
# 17        M4N         Central Toronto
# 18        M5N         Central Toronto
# 19        M4P         Central Toronto
# 20        M5P         Central Toronto
# 21        M6P            West Toronto
# 22        M4R         Central Toronto
# 23        M5R         Central Toronto
# 24        M6R            West Toronto
# 25        M4S         Central Toronto
# 26        M5S        Downtown Toronto
# 27        M6S            West Toronto
# 28        M4T         Central Toronto
# 29        M5T        Downtown Toronto
# 30        M4V         Central Toronto
# 31        M5V        Downtown Toronto
# 32        M4W        Downtown Toronto
# 33        M5W  Downtown Toronto Stn A
# 34        M4X        Downtown Toronto
# 35        M5X        Downtown Toronto
# 36        M4Y        Downtown Toronto
# 37        M7Y   East Toronto Business
#
#                                          Neighborhood   Latitude  Longitude  \
# 0                           Regent Park, Harbourfront  43.763573 -79.188711
# 1                            Garden District, Ryerson  43.692657 -79.264848
# 2                                      St. James Town  43.799525 -79.318389
# 3                                         The Beaches  43.786947 -79.385975
# 4                                  Central Bay Street  43.782736 -79.442259
# 5                                            Christie  43.753259 -79.329656
# 6                            Richmond, Adelaide, King  43.737473 -79.464763
# 7                        Dufferin, Dovercourt Village  43.739015 -79.506944
# 8                                  The Danforth  East  43.706397 -79.309937
# 9   Harbourfront East, Union Station, Toronto Islands  43.695344 -79.318389
# 10                           Little Portugal, Trinity  43.676357 -79.293031
# 11                       The Danforth West, Riverdale  43.679557 -79.352188
# 12           Toronto Dominion Centre, Design Exchange  43.668999 -79.315572
# 13       Brockton, Parkdale Village, Exhibition Place  43.659526 -79.340923
# 14                     India Bazaar, The Beaches West  43.704324 -79.388790
# 15                     Commerce Court, Victoria Hotel  43.689574 -79.383160
# 16                                    Studio District  43.657162 -79.378937
# 17                                      Lawrence Park  43.648198 -79.379817
# 18                                           Roselawn  43.733283 -79.419750
# 19                                   Davisville North  43.653206 -79.400049
# 20                           Forest Hill North & West  43.628947 -79.394420
# 21                      High Park, The Junction South  43.646435 -79.374846
# 22                                 North Toronto West  43.693781 -79.428191
# 23                The Annex, North Midtown, Yorkville  43.689026 -79.453512
# 24                             Parkdale, Roncesvalles  43.669542 -79.422564
# 25                                         Davisville  43.713756 -79.490074
# 26                     University of Toronto, Harbord  43.691116 -79.476013
# 27                                 Runnymede, Swansea  43.673185 -79.487262
# 28                        Moore Park, Summerhill East  43.648960 -79.456325
# 29          Kensington Market, Chinatown, Grange Park  43.651571 -79.484450
# 30  Summerhill West, Rathnelly, South Hill, Forest...  43.636966 -79.615819
# 31  CN Tower, King and Spadina, Railway Lands, Har...  43.662744 -79.321558
# 32                                           Rosedale  43.636258 -79.498509
# 33                                     Enclave of M5E  43.628841 -79.520999
# 34                        St. James Town, Cabbagetown  43.756303 -79.565963
# 35             First Canadian Place, Underground city  43.724766 -79.532242
# 36                               Church and Wellesley  43.696319 -79.532242
# 37                                     Enclave of M4L  43.688905 -79.554724
#
#     Cluster Labels 1st Most Common Venue  2nd Most Common Venue  \
# 0              1.0        Breakfast Spot         Medical Center
# 1              1.0          Skating Rink  General Entertainment
# 2              1.0        Breakfast Spot               Gym Pool
# 3              1.0   Japanese Restaurant     Chinese Restaurant
# 4              1.0         Grocery Store            Coffee Shop
# 5              2.0                  Park      Food & Drink Shop
# 6              0.0               Airport       Business Service
# 7              1.0                 Hotel                   Park
# 8              1.0           Pizza Place               Pharmacy
# 9              1.0          Skating Rink                   Park
# 10             1.0                   Pub                  Trail
# 11             1.0      Greek Restaurant            Coffee Shop
# 12             1.0                  Park   Fast Food Restaurant
# 13             1.0           Coffee Shop                Brewery
# 14             1.0          Dessert Shop            Pizza Place
# 15             1.0                  Park                  Trail
# 16             1.0           Coffee Shop         Clothing Store
# 17             1.0           Coffee Shop             Restaurant
# 18             1.0           Coffee Shop              Juice Bar
# 19             1.0                  Café            Coffee Shop
# 20             1.0        Airport Lounge        Airport Service
# 21             1.0           Coffee Shop     Seafood Restaurant
# 22             1.0                 Field                  Trail
# 23             0.0                  Park          Women's Store
# 24             1.0         Grocery Store                   Café
# 25             1.0                  Park                 Bakery
# 26             1.0        Discount Store      Convenience Store
# 27             1.0     Convenience Store         Breakfast Spot
# 28             1.0             Gift Shop         Breakfast Spot
# 29             1.0                  Café                    Pub
# 30             1.0           Coffee Shop                  Hotel
# 31             1.0            Comic Shop          Auto Workshop
# 32             3.0        Baseball Field            Yoga Studio
# 33             1.0     Convenience Store         Hardware Store
# 34             4.0                   Gym            Pizza Place
# 35             3.0        Baseball Field           Food Service
# 36             1.0           Coffee Shop            Pizza Place
# 37             1.0           Pizza Place         Sandwich Place
#
#         3rd Most Common Venue        4th Most Common Venue  \
# 0           Electronics Store                 Intersection
# 1             College Stadium                         Café
# 2                        Bank           Chinese Restaurant
# 3                        Bank                         Café
# 4                    Pharmacy                  Pizza Place
# 5                       Diner         Ethiopian Restaurant
# 6                        Park               Airport Lounge
# 7               Grocery Store                Shopping Mall
# 8                        Café                  Flea Market
# 9                  Beer Store                          Spa
# 10           Asian Restaurant            Health Food Store
# 11         Italian Restaurant                    Bookstore
# 12              Movie Theater                   Playground
# 13                       Café          American Restaurant
# 14             Sandwich Place                  Coffee Shop
# 15                 Playground                   Restaurant
# 16  Middle Eastern Restaurant              Bubble Tea Shop
# 17                       Café                        Hotel
# 18             Sandwich Place           Italian Restaurant
# 19         Mexican Restaurant        Vietnamese Restaurant
# 20           Airport Terminal                      Airport
# 21         Italian Restaurant          Japanese Restaurant
# 22               Tennis Court                 Hockey Arena
# 23                       Pool                  Yoga Studio
# 24                       Park           Italian Restaurant
# 25           Basketball Court   Construction & Landscaping
# 26                Coffee Shop               Sandwich Place
# 27                Pizza Place                      Brewery
# 28                  Bookstore  Eastern European Restaurant
# 29                Pizza Place           Italian Restaurant
# 30             Sandwich Place                  Gas Station
# 31                 Restaurant                Burrito Place
# 32             Discount Store           Falafel Restaurant
# 33       Fast Food Restaurant                 Burger Joint
# 34     Furniture / Home Store                  Yoga Studio
# 35                Yoga Studio         Fast Food Restaurant
# 36             Sandwich Place                   Playground
# 37                   Bus Line            Mobile Phone Shop
#
#             5th Most Common Venue        6th Most Common Venue  \
# 0                      Restaurant          Rental Car Location
# 1                           Diner         Ethiopian Restaurant
# 2                    Intersection                  Pizza Place
# 3                     Yoga Studio          Distribution Center
# 4                     Supermarket                  Yoga Studio
# 5               Electronics Store  Eastern European Restaurant
# 6            Fast Food Restaurant           Falafel Restaurant
# 7                            Bank                  Yoga Studio
# 8                    Intersection           Athletics & Sports
# 9                     Curling Ice           Athletics & Sports
# 10                    Yoga Studio         Ethiopian Restaurant
# 11                 Ice Cream Shop       Furniture / Home Store
# 12                 Sandwich Place                   Restaurant
# 13                         Bakery                    Gastropub
# 14             Italian Restaurant             Sushi Restaurant
# 15                    Yoga Studio             Department Store
# 16                 Cosmetics Shop          Japanese Restaurant
# 17                            Gym           Italian Restaurant
# 18                     Hobby Shop      Comfort Food Restaurant
# 19  Vegetarian / Vegan Restaurant                          Bar
# 20                    Coffee Shop          Rental Car Location
# 21                     Restaurant                     Beer Bar
# 22                   Dessert Shop         Ethiopian Restaurant
# 23                   Dessert Shop            Electronics Store
# 24                      Nightclub                   Baby Store
# 25                        Gay Bar                        Diner
# 26                            Bar                  Yoga Studio
# 27                    Yoga Studio               Discount Store
# 28                           Bank                      Dog Run
# 29                    Coffee Shop             Sushi Restaurant
# 30                  Burrito Place          American Restaurant
# 31               Recording Studio                   Skate Park
# 32           Ethiopian Restaurant            Electronics Store
# 33                  Burrito Place               Discount Store
# 34                   Dessert Shop            Electronics Store
# 35             Falafel Restaurant         Ethiopian Restaurant
# 36             Chinese Restaurant                 Intersection
# 37                    Yoga Studio                        Diner
#
#           7th Most Common Venue        8th Most Common Venue  \
# 0                          Bank           Mexican Restaurant
# 1             Electronics Store  Eastern European Restaurant
# 2                  Camera Store                     Pharmacy
# 3            Falafel Restaurant         Ethiopian Restaurant
# 4                  Dessert Shop  Eastern European Restaurant
# 5           Dumpling Restaurant                   Donut Shop
# 6          Ethiopian Restaurant            Electronics Store
# 7          Ethiopian Restaurant            Electronics Store
# 8                          Bank         Gym / Fitness Center
# 9           Distribution Center           Falafel Restaurant
# 10            Electronics Store  Eastern European Restaurant
# 11                       Lounge                  Pizza Place
# 12           Italian Restaurant           Light Rail Station
# 13                  Yoga Studio      Comfort Food Restaurant
# 14                         Café                          Gym
# 15  Eastern European Restaurant          Dumpling Restaurant
# 16                         Café                    Bookstore
# 17          Japanese Restaurant                Deli / Bodega
# 18                     Pharmacy                  Pizza Place
# 19                       Bakery          Arts & Crafts Store
# 20                Boat or Ferry                          Bar
# 21                        Hotel                 Cocktail Bar
# 22            Electronics Store  Eastern European Restaurant
# 23  Eastern European Restaurant          Dumpling Restaurant
# 24                  Candy Store                  Coffee Shop
# 25         Ethiopian Restaurant            Electronics Store
# 26         Ethiopian Restaurant            Electronics Store
# 27         Ethiopian Restaurant            Electronics Store
# 28                   Restaurant                 Dessert Shop
# 29                  Yoga Studio                  Fish Market
# 30                          Gym                 Intersection
# 31           Light Rail Station               Farmers Market
# 32  Eastern European Restaurant          Dumpling Restaurant
# 33                       Bakery              Supplement Shop
# 34  Eastern European Restaurant          Dumpling Restaurant
# 35            Electronics Store  Eastern European Restaurant
# 36               Discount Store                  Yoga Studio
# 37            Electronics Store  Eastern European Restaurant
#
#           9th Most Common Venue       10th Most Common Venue
# 0   Eastern European Restaurant          Dumpling Restaurant
# 1           Dumpling Restaurant                   Donut Shop
# 2                   Coffee Shop         Fast Food Restaurant
# 3             Electronics Store  Eastern European Restaurant
# 4           Dumpling Restaurant                   Donut Shop
# 5              Doner Restaurant                      Dog Run
# 6   Eastern European Restaurant          Dumpling Restaurant
# 7   Eastern European Restaurant          Dumpling Restaurant
# 8                     Gastropub               Discount Store
# 9          Ethiopian Restaurant            Electronics Store
# 10          Dumpling Restaurant                   Donut Shop
# 11         Caribbean Restaurant                         Café
# 12                          Pub               Ice Cream Shop
# 13                  Cheese Shop               Clothing Store
# 14                     Pharmacy                   Restaurant
# 15                   Donut Shop             Doner Restaurant
# 16             Ramen Restaurant            Electronics Store
# 17           Seafood Restaurant          American Restaurant
# 18                 Liquor Store                         Café
# 19                         Park                  Gaming Cafe
# 20                        Plane              Harbor / Marina
# 21                         Café               Sandwich Place
# 22          Dumpling Restaurant                   Donut Shop
# 23                   Donut Shop             Doner Restaurant
# 24                   Restaurant           Athletics & Sports
# 25  Eastern European Restaurant          Dumpling Restaurant
# 26  Eastern European Restaurant          Dumpling Restaurant
# 27  Eastern European Restaurant          Dumpling Restaurant
# 28           Italian Restaurant                  Coffee Shop
# 29    Latin American Restaurant          Indie Movie Theater
# 30          Fried Chicken Joint     Mediterranean Restaurant
# 31         Fast Food Restaurant                          Spa
# 32                   Donut Shop             Doner Restaurant
# 33               Sandwich Place                Tanning Salon
# 34                   Donut Shop             Doner Restaurant
# 35          Dumpling Restaurant                   Donut Shop
# 36                        Diner  Eastern European Restaurant
# 37          Dumpling Restaurant                   Donut Shop

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(Toronto_merged['Latitude'], Toronto_merged['Longitude'], Toronto_merged['Neighborhood'], Toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster-1)],
        fill=True,
        fill_color=rainbow[int(cluster-1)],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_3592238eb0e74667bf8eed16357adaca%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3592238eb0e74667bf8eed16357adaca%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_3592238eb0e74667bf8eed16357adaca%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_3592238eb0e74667bf8eed16357adaca%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...
