# %% [markdown]
# # Clustering Fort Worth neighborhoods

# %% [markdown]
# ## Imports/Installs

# %%
import numpy as np
import pandas as pd
import json
import geocoder
from geopy.geocoders import Nominatim
import requests
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium

# %% [markdown]
# ## Pre-processing

# %%
#Bring in csv of neighborhoods and create initial dataframe
hoods = pd.read_csv('C:/Users/Administrator.Sergio-PC/Desktop/Fort Worth Neighborhoods.csv')
hoods.columns = ['Neighborhood']

# %%
#Split on backslash, keep first name 
hoods_split = pd.DataFrame(hoods['Neighborhood'].str.split("\\",1))
hoods_split['Neighborhood'] = hoods_split['Neighborhood'].str[0]

# %%
#Remove words 'Greater' and 'Near' from neighborhood names so they can be located
hoods_split['Neighborhood'] = hoods_split['Neighborhood'].str.replace('Greater','')
hoods_split['Neighborhood'] = hoods_split['Neighborhood'].str.replace('Near','')
#hoods_split

# %%
#initialize user agent for geolocator
geolocator = Nominatim(user_agent = 'foros_explorer')
# Create a test function to get latitude and longitude

def getcoords(name):
    address = '{},Fort Worth'.format(name)
    location = geolocator.geocode(address)
    lat = location.latitude
    long = location.longitude
    print(lat,long)

# %%
# delete neighborhoods from dataframe that we cannot find latitude and longitude for
List = ['Far South','Fort Worth Nature Center','Far West','Greater 287 Corridor','Harriet Creek Ranch',"Historic Randol's Mill",'Historic Southside']

hoods_split = hoods_split[~hoods_split['Neighborhood'].isin(List)]

hoods_split.reset_index(drop=True,inplace=True)

hoods_split
# Out:
#            Neighborhood
# 0      Alliance Gateway
# 1         Benbrook Lake
# 2            Centreport
# 3             Clearfork
# 4   Diamond Hill-Jarvis
# 5        Eagle Mountain
# 6          Fossil Creek
# 7          Garden Acres
# 8          Gateway Park
# 9          287 Corridor
# 10          Candleridge
# 11         Chapel Creek
# 12            City View
# 13                 Como
# 14             Downtown
# 15             Hemphill
# 16             Hillside
# 17         Marine Creek
# 18          Polytechnic
# 19              Ridglea
# 20            Riverside
# 21             Seminary
# 22            Southeast
# 23         Summer Creek
# 24                  TCU
# 25             Hallmark
# 26              Handley
# 27             Heritage
# 28       Highland Hills
# 29       Lake Arlington
# 30           Lake Worth
# 31              Meacham
# 32      Meacham Airport
# 33          Meadowbrook
# 34        Mosier Valley
# 35            Southside
# 36             Westside
# 37            Northside
# 38     Oakridge Terrace
# 39            Park Glen
# 40       Rosemary Ridge
# 41             Ryanwood
# 42        Sendera Ranch
# 43      Seventeen Lakes
# 44             Stop Six
# 45         Summerfields
# 46         Tehama Ridge
# 47      Thomas Crossing
# 48                  TMS
# 49          Walsh Ranch
# 50             Wedgwood
# 51        Western Hills
# 52          Wise County
# 53            Woodhaven

# %%
#Test to check for neighborhoods that can't be found
index=0
for hood in hoods_split['Neighborhood']:
    getcoords(hood)
    print('Index {}'.format(index))
    index+=1
# Out:
# 32.9597161 -97.3098371
# Index 0
# 32.6251539 -97.46958117898197
# Index 1
# 32.8169726 -97.052651
# Index 2
# 32.70799605 -97.39964903824261
# Index 3
# 32.8084707 -97.33687884817545
# Index 4
# 32.8934599 -97.4444646
# Index 5
# 32.89313675 -97.29671143940243
# Index 6
# 32.5945803 -97.3025153
# Index 7
# 32.7585519 -97.27186768992246
# Index 8
# 57.2304195 -111.4272347
# Index 9
# 32.6408712 -97.38599811582664
# Index 10
# 38.813932 -77.098963
# Index 11
# 32.753177 -97.3327459
# Index 12
# 32.72021675 -97.41073038861262
# Index 13
# 32.75397915 -97.32953315949203
# Index 14
# 32.6663647 -97.3318397
# Index 15
# 32.729365 -97.31251196491371
# Index 16
# 32.7886211 -97.3483917
# Index 17
# 32.7321685 -97.28843178003808
# Index 18
# 32.719586750000005 -97.41421914933309
# Index 19
# 32.689791 -97.26180935
# Index 20
# 32.6803248 -97.34822416089753
# Index 21
# 32.753177 -97.3327459
# Index 22
# 32.618375 -97.39772844110882
# Index 23
# 32.70269385 -97.36855768763164
# Index 24
# 32.61584015 -97.38471728541448
# Index 25
# 32.7326315 -97.2180688
# Index 26
# 32.902016399999994 -97.2654930581567
# Index 27
# 32.661911700000005 -97.30031888295636
# Index 28
# 32.6982046 -97.21089984702272
# Index 29
# 32.81468075 -97.48109113974844
# Index 30
# 32.8196935 -97.35968955703422
# Index 31
# 32.8196935 -97.35968955703422
# Index 32
# 32.743231699999995 -97.28500610268384
# Index 33
# 32.80477105 -97.12141428763067
# Index 34
# 32.7206604 -97.3308933387853
# Index 35
# 32.72555245 -97.47776635172231
# Index 36
# 32.769181 -97.356126
# Index 37
# 32.818073 -97.054049
# Index 38
# 32.8834719 -97.2791855
# Index 39
# 32.59310885 -97.38748157859527
# Index 40
# 32.7585439 -97.20280059937096
# Index 41
# 32.9889868 -97.3933468
# Index 42
# 32.9999166 -97.26341900212904
# Index 43
# 32.7125496 -97.25648048175535
# Index 44
# 32.888421050000005 -97.29914594001141
# Index 45
# 32.9069651 -97.3224094
# Index 46
# 32.7408736 -97.37984374999999
# Index 47
# 33.033070499999994 -97.27408233850599
# Index 48
# 32.73730435 -97.5701952804556
# Index 49
# 32.6634636 -97.3945627
# Index 50
# 32.72013575 -97.47125920572124
# Index 51
# 32.89677485 -97.31265874496627
# Index 52
# 32.762467 -97.240127
# Index 53

# %%
#Define Variable that will become columns, and new function to append coordinates
Latitude = []
Longitude = []

def getcoords(name):
    address = '{},Fort Worth'.format(name)
    location = geolocator.geocode(address)
    lat = location.latitude
    long = location.longitude
    Latitude.append(lat)
    Longitude.append(long)

# %%
#iterate over all neighborhoods
for hood in hoods_split['Neighborhood']:
    getcoords(hood)

# %%
#append lat and long to datadrame
hoods_split['Latitude'] = Latitude
hoods_split['Longitude'] = Longitude
hoods_split
# Out:
#            Neighborhood   Latitude   Longitude
# 0      Alliance Gateway  32.959716  -97.309837
# 1         Benbrook Lake  32.625154  -97.469581
# 2            Centreport  32.816973  -97.052651
# 3             Clearfork  32.707996  -97.399649
# 4   Diamond Hill-Jarvis  32.808471  -97.336879
# 5        Eagle Mountain  32.893460  -97.444465
# 6          Fossil Creek  32.893137  -97.296711
# 7          Garden Acres  32.594580  -97.302515
# 8          Gateway Park  32.758552  -97.271868
# 9          287 Corridor  57.230420 -111.427235
# 10          Candleridge  32.640871  -97.385998
# 11         Chapel Creek  38.813932  -77.098963
# 12            City View  32.753177  -97.332746
# 13                 Como  32.720217  -97.410730
# 14             Downtown  32.753979  -97.329533
# 15             Hemphill  32.666365  -97.331840
# 16             Hillside  32.729365  -97.312512
# 17         Marine Creek  32.788621  -97.348392
# 18          Polytechnic  32.732169  -97.288432
# 19              Ridglea  32.719587  -97.414219
# 20            Riverside  32.689791  -97.261809
# 21             Seminary  32.680325  -97.348224
# 22            Southeast  32.753177  -97.332746
# 23         Summer Creek  32.618375  -97.397728
# 24                  TCU  32.702694  -97.368558
# 25             Hallmark  32.615840  -97.384717
# 26              Handley  32.732631  -97.218069
# 27             Heritage  32.902016  -97.265493
# 28       Highland Hills  32.661912  -97.300319
# 29       Lake Arlington  32.698205  -97.210900
# 30           Lake Worth  32.814681  -97.481091
# 31              Meacham  32.819693  -97.359690
# 32      Meacham Airport  32.819693  -97.359690
# 33          Meadowbrook  32.743232  -97.285006
# 34        Mosier Valley  32.804771  -97.121414
# 35            Southside  32.720660  -97.330893
# 36             Westside  32.725552  -97.477766
# 37            Northside  32.769181  -97.356126
# 38     Oakridge Terrace  32.818073  -97.054049
# 39            Park Glen  32.883472  -97.279185
# 40       Rosemary Ridge  32.593109  -97.387482
# 41             Ryanwood  32.758544  -97.202801
# 42        Sendera Ranch  32.988987  -97.393347
# 43      Seventeen Lakes  32.999917  -97.263419
# 44             Stop Six  32.712550  -97.256480
# 45         Summerfields  32.888421  -97.299146
# 46         Tehama Ridge  32.906965  -97.322409
# 47      Thomas Crossing  32.740874  -97.379844
# 48                  TMS  33.033070  -97.274082
# 49          Walsh Ranch  32.737304  -97.570195
# 50             Wedgwood  32.663464  -97.394563
# 51        Western Hills  32.720136  -97.471259
# 52          Wise County  32.896775  -97.312659
# 53            Woodhaven  32.762467  -97.240127

# %% [markdown]
# ## Create a map of Fort Worth

# %%
fw = geolocator.geocode('Fort Worth, Texas')
fw_latitude = fw.latitude
fw_longitude = fw.longitude

#Create a map of Fort Worth using our coordinates

map_Fort_Worth = folium.Map(location = [fw_latitude,fw_longitude], zoom_start = 10)

map_Fort_Worth
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_643bae0a26ef4ba3a99610900aafdc01%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_643bae0a26ef4ba3a99610900aafdc01%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_643bae0a26ef4ba3a99610900aafdc01%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_643bae0a26ef4ba3a99610900aafdc01%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B32.753177%2C%20-97.3327459%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ## Use foursquare API to explore neighborhoods

# %% [markdown]
# Start by defining user credentials

# %%
CLIENT_ID = 'DVLMGSHW5ZXGOPKUJIMG0P4TH4CRUQ0K3AYQCFO3VEK4MOCK'
CLIENT_SECRET = 'RKEGR051LSDZEPTWUROZ3NPPSY5DXXWKGLYYW4EYPFGEDP03'
ACCESS_TOKEN = 'CQWUXEOI30MJUDWUD2Z2NMAUX3F22IPEWAREZPCJXI2OBRSF'
VERSION = '20180605'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: DVLMGSHW5ZXGOPKUJIMG0P4TH4CRUQ0K3AYQCFO3VEK4MOCK
# CLIENT_SECRET:RKEGR051LSDZEPTWUROZ3NPPSY5DXXWKGLYYW4EYPFGEDP03

# %% [markdown]
# Next, we define function(s) to extract venue category and to get nearby venues

# %%
def getNearbyVenues(names,latitudes,longitudes,radius=500):
    venues_list = []
    for name,lat,lng in zip(names,latitudes,longitudes):
        print(name)
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID,CLIENT_SECRET,VERSION,lat,lng,radius,LIMIT)
        results = requests.get(url).json()['response']['groups'][0]['items']
        venues_list.append([(name,lat,lng,v['venue']['name'],v['venue']['location']['lat'],v['venue']['location']['lng'],v['venue']['categories'][0]['name']) for v in results])
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood','Neighborhood latitude','Neighborhood longitude','Venue','Venue latitude','Venue longitude','Venue category']
    return(nearby_venues)

# %% [markdown]
# Get the nearby venues for all of the neighborhoods in Fort Worth and store them in a new dataframe

# %%
fw_venues = getNearbyVenues(names=hoods_split['Neighborhood'],latitudes=hoods_split['Latitude'],longitudes=hoods_split['Longitude'])

fw_venues.head()
# Out:
# Alliance Gateway
# Benbrook Lake
# Centreport
# Clearfork
# Diamond Hill-Jarvis
# Eagle Mountain
# Fossil Creek
# Garden Acres
# Gateway Park
#  287 Corridor
#  Candleridge
#  Chapel Creek
#  City View
#  Como
#  Downtown
#  Hemphill
#  Hillside
#  Marine Creek
#  Polytechnic
#  Ridglea
#  Riverside
#  Seminary
#  Southeast
#  Summer Creek
#  TCU
# Hallmark
# Handley
# Heritage
# Highland Hills
# Lake Arlington
# Lake Worth
# Meacham
# Meacham Airport
# Meadowbrook
# Mosier Valley
#  Southside
#  Westside
# Northside
# Oakridge Terrace
# Park Glen
# Rosemary Ridge
# Ryanwood
# Sendera Ranch
# Seventeen Lakes
# Stop Six
# Summerfields
# Tehama Ridge
# Thomas Crossing
# TMS
# Walsh Ranch
# Wedgwood
# Western Hills
# Wise County
# Woodhaven
#        Neighborhood  Neighborhood latitude  Neighborhood longitude  \
# 0  Alliance Gateway              32.959716              -97.309837
# 1  Alliance Gateway              32.959716              -97.309837
# 2  Alliance Gateway              32.959716              -97.309837
# 3  Alliance Gateway              32.959716              -97.309837
# 4  Alliance Gateway              32.959716              -97.309837
#
#                        Venue  Venue latitude  Venue longitude  \
# 0                   Cabela's       32.961010       -97.308356
# 1  Hill Overlooking Alliance       32.957735       -97.309287
# 2                       IHOP       32.957353       -97.308843
# 3                     SUBWAY       32.957701       -97.307488
# 4       Pilot Travel Centers       32.957734       -97.306777
#
#         Venue category
# 0  Sporting Goods Shop
# 1       Scenic Lookout
# 2       Breakfast Spot
# 3       Sandwich Place
# 4          Gas Station

# %% [markdown]
# ##  Analyze the neighborhoods

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#one hot encoding
fw_onehot = pd.get_dummies(fw_venues[['Venue category']],prefix="",prefix_sep="")

#add neighborhood column to our new onehot dataframe
fw_onehot['Neighborhood'] = fw_venues['Neighborhood']

# %%
#group rows by neighborhood and mean occurance of categories

fw_grouped = fw_onehot.groupby('Neighborhood').mean().reset_index()

#print shape to confirm changes
fw_grouped.shape
# Out:
# (47, 150)

# %% [markdown]
# ## Get most common venues and put them into a dataframe

# %%
#Define a function that sorts venues in descending order

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
#create dataframe to display top 10 venues for each neighborhood

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = fw_grouped['Neighborhood']

for ind in np.arange(fw_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(fw_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#     Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0   287 Corridor           Coffee Shop               Airport
# 1    Candleridge                  Park                  Food
# 2   Chapel Creek   Sporting Goods Shop    Mexican Restaurant
# 3      City View                 Hotel   American Restaurant
# 4           Como        Discount Store        Clothing Store
#
#   3rd Most Common Venue 4th Most Common Venue       5th Most Common Venue  \
# 0        Discount Store           Flea Market        Fast Food Restaurant
# 1               Dog Run                  Lake  Construction & Landscaping
# 2            Vape Store   Rental Car Location                        Park
# 3           Coffee Shop                  Park              Sandwich Place
# 4                   Gym              Wine Bar        Fast Food Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0           Fabric Shop  Ethiopian Restaurant     Electronics Store
# 1     Convenience Store         Deli / Bodega      Department Store
# 2        Shipping Store          Dessert Shop  Ethiopian Restaurant
# 3            Steakhouse                Lounge    Seafood Restaurant
# 4           Fabric Shop  Ethiopian Restaurant     Electronics Store
#
#      9th Most Common Venue 10th Most Common Venue
# 0               Donut Shop                Dog Run
# 1             Dessert Shop      Fondue Restaurant
# 2        Electronics Store             Donut Shop
# 3  New American Restaurant               Beer Bar
# 4               Donut Shop                Dog Run

# %% [markdown]
# ## Cluster the neighborhoods

# %% [markdown]
#  Run K-Means and split the neighborhoods into 5 clusters

# %%
# set number of clusters
kclusters = 5

fw_grouped_clustering = fw_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(fw_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([2, 0, 2, 2, 2, 2, 2, 2, 2, 2])

# %% [markdown]
# Create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

fw_merged = hoods_split

# merge Toronto_grouped with df_Toronto to add latitude/longitude for each neighborhood
fw_merged = fw_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

fw_merged.shape
# Out:
# (54, 14)

# %%
#Drop rows with Nan values
fw_merged.dropna(inplace=True)
fw_merged.reset_index(drop=True,inplace=True)
fw_merged.shape
# Out:
# (47, 14)

# %% [markdown]
# Finally, let's visualize the resulting clusters

# %%
# create map
map_clusters = folium.Map(location=[fw_latitude, fw_longitude], zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(fw_merged['Latitude'], fw_merged['Longitude'], fw_merged['Neighborhood'], fw_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster-1)],
        fill=True,
        fill_color=rainbow[int(cluster-1)],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_b23e66c0718e4b08a5a076a2b325286e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_b23e66c0718e4b08a5a076a2b325286e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_b23e66c0718e4b08a5a076a2b325286e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_b23e66c0718e4b08a5a076a2b325286e%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B32.753177%2C%20-97.3327459%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ## Examine clusters

# %%
fw_merged.head()
# Out:
#           Neighborhood   Latitude  Longitude  Cluster Labels  \
# 0     Alliance Gateway  32.959716 -97.309837             2.0
# 1        Benbrook Lake  32.625154 -97.469581             4.0
# 2           Centreport  32.816973 -97.052651             1.0
# 3            Clearfork  32.707996 -97.399649             2.0
# 4  Diamond Hill-Jarvis  32.808471 -97.336879             2.0
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0                   ATM           Gas Station        Sandwich Place
# 1                Circus              Wine Bar        Discount Store
# 2                 Trail              Wine Bar          Dessert Shop
# 3   American Restaurant        Shopping Plaza     French Restaurant
# 4        Discount Store     Recreation Center    Mexican Restaurant
#
#   4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0        Scenic Lookout        Breakfast Spot  Fast Food Restaurant
# 1  Fast Food Restaurant           Fabric Shop  Ethiopian Restaurant
# 2  Fast Food Restaurant           Fabric Shop  Ethiopian Restaurant
# 3         Bowling Alley              Boutique               Dog Run
# 4         Grocery Store     Convenience Store   Fried Chicken Joint
#
#   7th Most Common Venue            8th Most Common Venue  \
# 0   Sporting Goods Shop                    Grocery Store
# 1     Electronics Store                       Donut Shop
# 2     Electronics Store                       Donut Shop
# 3         Movie Theater  Southern / Soul Food Restaurant
# 4              Wine Bar             Ethiopian Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 0     Electronics Store            Comedy Club
# 1               Dog Run           Dessert Shop
# 2               Dog Run         Discount Store
# 3   Leather Goods Store                    Bar
# 4     Electronics Store             Donut Shop

# %%
cluster = input('Choose cluster: ')
fw_merged.loc[fw_merged['Cluster Labels'] == int(cluster), fw_merged.columns[[0] + list(range(4, fw_merged.shape[1]))]]
# Out:
# Choose cluster: 2
#            Neighborhood     1st Most Common Venue       2nd Most Common Venue  \
# 0      Alliance Gateway                       ATM                 Gas Station
# 3             Clearfork       American Restaurant              Shopping Plaza
# 4   Diamond Hill-Jarvis            Discount Store           Recreation Center
# 6          Fossil Creek            Baseball Field                 Pizza Place
# 7          287 Corridor               Coffee Shop                     Airport
# 9          Chapel Creek       Sporting Goods Shop          Mexican Restaurant
# 10            City View                     Hotel         American Restaurant
# 11                 Como            Discount Store              Clothing Store
# 12             Downtown                     Hotel         American Restaurant
# 13             Hemphill                Public Art                         Gym
# 14             Hillside            Sandwich Place                         Bar
# 15         Marine Creek                       Bar          Mexican Restaurant
# 16          Polytechnic          Community Center           Convenience Store
# 17              Ridglea               Golf Course              Clothing Store
# 19             Seminary      Fast Food Restaurant                    Wine Bar
# 20            Southeast                     Hotel         American Restaurant
# 22                  TCU  College Baseball Diamond                  Playground
# 23             Hallmark      Fast Food Restaurant                 Pizza Place
# 24              Handley                       Bar          Miscellaneous Shop
# 25             Heritage        Athletics & Sports                        Pool
# 26       Highland Hills           Warehouse Store                   Nightclub
# 27              Meacham          Airport Terminal                     Airport
# 28      Meacham Airport          Airport Terminal                     Airport
# 29          Meadowbrook                   Gay Bar  Construction & Landscaping
# 30            Southside        Mexican Restaurant                Liquor Store
# 31             Westside               Pizza Place        Fast Food Restaurant
# 32            Northside               Flea Market                  Food Truck
# 36             Ryanwood               Music Venue                         Gym
# 38             Stop Six                      Food        Fast Food Restaurant
# 39         Summerfields              Home Service              Baseball Field
# 40         Tehama Ridge        Mexican Restaurant            Department Store
# 42                  TMS                 Racetrack                  Sports Bar
# 43          Walsh Ranch         Convenience Store                    Wine Bar
# 45          Wise County             Auto Workshop                 Video Store
# 46            Woodhaven            Discount Store                  Restaurant
#
#     3rd Most Common Venue  4th Most Common Venue       5th Most Common Venue  \
# 0          Sandwich Place         Scenic Lookout              Breakfast Spot
# 3       French Restaurant          Bowling Alley                    Boutique
# 4      Mexican Restaurant          Grocery Store           Convenience Store
# 6                  Market               Wine Bar                     Dog Run
# 7          Discount Store            Flea Market        Fast Food Restaurant
# 9              Vape Store    Rental Car Location                        Park
# 10            Coffee Shop                   Park              Sandwich Place
# 11                    Gym               Wine Bar        Fast Food Restaurant
# 12         Sandwich Place            Coffee Shop                  Steakhouse
# 13          Grocery Store          Deli / Bodega                 Gas Station
# 14       Basketball Court                  Motel  Construction & Landscaping
# 15           Burger Joint             Steakhouse              Clothing Store
# 16     Mexican Restaurant               Wine Bar                  Donut Shop
# 17                    Gym         Discount Store                Dessert Shop
# 19      Fondue Restaurant            Fabric Shop        Ethiopian Restaurant
# 20            Coffee Shop                   Park              Sandwich Place
# 22           Tennis Court           Dessert Shop                 Fabric Shop
# 23               Pharmacy             Nail Salon                 Video Store
# 24            Bridal Shop    American Restaurant                      Lounge
# 25             Donut Shop           Dessert Shop        Fast Food Restaurant
# 26      Fondue Restaurant   Fast Food Restaurant                 Fabric Shop
# 27        Airport Service           Home Service         Rental Car Location
# 28        Airport Service           Home Service         Rental Car Location
# 29      Convenience Store     Mexican Restaurant                         Bar
# 30              Rock Club  Salvadoran Restaurant                    Wine Bar
# 31        Thai Restaurant      Convenience Store                        Café
# 32                   Café         Discount Store        Fast Food Restaurant
# 36           Camera Store               Wine Bar              Discount Store
# 38            Snack Place      Electronics Store              Discount Store
# 39                 Arcade                Dog Run                 Flea Market
# 40              Bookstore            Music Store                  Restaurant
# 42  Performing Arts Venue     Athletics & Sports              Discount Store
# 43         Discount Store   Fast Food Restaurant                 Fabric Shop
# 45                   Pool      Convenience Store                  Taco Place
# 46                 Lounge           Liquor Store                 Gas Station
#
#             6th Most Common Venue 7th Most Common Venue  \
# 0            Fast Food Restaurant   Sporting Goods Shop
# 3                         Dog Run         Movie Theater
# 4             Fried Chicken Joint              Wine Bar
# 6            Fast Food Restaurant           Fabric Shop
# 7                     Fabric Shop  Ethiopian Restaurant
# 9                  Shipping Store          Dessert Shop
# 10                     Steakhouse                Lounge
# 11                    Fabric Shop  Ethiopian Restaurant
# 12                         Lounge                  Park
# 13                 Discount Store           Fabric Shop
# 14              Electronics Store           Flea Market
# 15                  Historic Site             BBQ Joint
# 16                    Flea Market  Fast Food Restaurant
# 17                    Fabric Shop  Ethiopian Restaurant
# 19              Electronics Store            Donut Shop
# 20                     Steakhouse                Lounge
# 22           Ethiopian Restaurant     Electronics Store
# 23            American Restaurant           IT Services
# 24  Paper / Office Supplies Store                Bakery
# 25                    Fabric Shop  Ethiopian Restaurant
# 26           Ethiopian Restaurant     Electronics Store
# 27                       Wine Bar        Discount Store
# 28                       Wine Bar        Discount Store
# 29                       Wine Bar  Fast Food Restaurant
# 30                   Dessert Shop  Ethiopian Restaurant
# 31                 Sandwich Place         Movie Theater
# 32                    Fabric Shop  Ethiopian Restaurant
# 36                    Fabric Shop  Ethiopian Restaurant
# 38                    Fabric Shop  Ethiopian Restaurant
# 39           Fast Food Restaurant           Fabric Shop
# 40                    Supermarket    Tex-Mex Restaurant
# 42           Fast Food Restaurant           Fabric Shop
# 43           Ethiopian Restaurant     Electronics Store
# 45                       Wine Bar           Fabric Shop
# 46                        Dog Run           Fabric Shop
#
#               8th Most Common Venue    9th Most Common Venue  \
# 0                     Grocery Store        Electronics Store
# 3   Southern / Soul Food Restaurant      Leather Goods Store
# 4              Ethiopian Restaurant        Electronics Store
# 6              Ethiopian Restaurant        Electronics Store
# 7                 Electronics Store               Donut Shop
# 9              Ethiopian Restaurant        Electronics Store
# 10               Seafood Restaurant  New American Restaurant
# 11                Electronics Store               Donut Shop
# 12               Seafood Restaurant  New American Restaurant
# 13             Ethiopian Restaurant        Electronics Store
# 14             Fast Food Restaurant         Community Center
# 15                            Hotel  New American Restaurant
# 16                      Fabric Shop     Ethiopian Restaurant
# 17                Electronics Store               Donut Shop
# 19                          Dog Run           Discount Store
# 20               Seafood Restaurant  New American Restaurant
# 22                       Donut Shop                  Dog Run
# 23               Mexican Restaurant       Italian Restaurant
# 24                Electronics Store              Flea Market
# 25                Electronics Store                  Dog Run
# 26                       Donut Shop                  Dog Run
# 27             Fast Food Restaurant              Fabric Shop
# 28             Fast Food Restaurant              Fabric Shop
# 29                      Fabric Shop     Ethiopian Restaurant
# 30                Electronics Store               Donut Shop
# 31                  Motorcycle Shop              Supermarket
# 32                Electronics Store               Donut Shop
# 36                Electronics Store               Donut Shop
# 38                       Donut Shop                  Dog Run
# 39             Ethiopian Restaurant        Electronics Store
# 40                        Juice Bar                   Arcade
# 42             Ethiopian Restaurant        Electronics Store
# 43                       Donut Shop                  Dog Run
# 45             Ethiopian Restaurant        Electronics Store
# 46             Ethiopian Restaurant        Electronics Store
#
#    10th Most Common Venue
# 0             Comedy Club
# 3                     Bar
# 4              Donut Shop
# 6              Donut Shop
# 7                 Dog Run
# 9              Donut Shop
# 10               Beer Bar
# 11                Dog Run
# 12               Beer Bar
# 13             Donut Shop
# 14            Fabric Shop
# 15                   Café
# 16      Electronics Store
# 17                Dog Run
# 19           Dessert Shop
# 20               Beer Bar
# 22         Discount Store
# 23      Convenience Store
# 24   Fast Food Restaurant
# 25         Discount Store
# 26         Discount Store
# 27   Ethiopian Restaurant
# 28   Ethiopian Restaurant
# 29      Electronics Store
# 30                Dog Run
# 31        Auto Dealership
# 32                Dog Run
# 36                Dog Run
# 38               Wine Bar
# 39             Donut Shop
# 40          Grocery Store
# 42             Donut Shop
# 43           Dessert Shop
# 45             Donut Shop
# 46             Donut Shop
